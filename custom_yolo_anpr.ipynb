# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Thu Aug 18 11:26:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls "/content/drive/MyDrive/car_license"
# Out:
# 'License Plates.v1i.darknet.zip'

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
! git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15490, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 15490 (delta 10), reused 18 (delta 8), pack-reused 15460
# Receiving objects: 100% (15490/15490), 14.10 MiB | 8.48 MiB/s, done.
# Resolving deltas: 100% (10397/10397), done.
# Checking out files: 100% (2057/2057), done.

# %%
# %cd darknet 
! make
# Out:
# /content/drive/MyDrive/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
! python convert.py
# Out:
# Finished processing: train
# Finished processing: test

# %%
! mkdir my_data
# Out:
# mkdir: cannot create directory ‘my_data’: File exists

# %%
! mv train.txt my_data/ 
! mv test.txt my_data/

# %%
! touch /content/drive/MyDrive/darknet/my_data/classes.names
! echo LP > /content/drive/MyDrive/darknet/my_data/classes.names

# %%
! mkdir my_data/weights

# %%
! touch /content/drive/MyDrive/darknet/my_data/darknet.data

# %%
! cp /content/drive/MyDrive/darknet/cfg/yolov3.cfg /content/drive/MyDrive/darknet/my_data

# %%
! wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-08-18 12:21:22--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  15.3MB/s    in 11s
#
# 2022-08-18 12:21:34 (14.3 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
! ./darknet detector train \
/content/drive/MyDrive/darknet/my_data/darknet.data \
/content/drive/MyDrive/darknet/my_data/yolov3.cfg \
/content/drive/MyDrive/darknet/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 36681, rewritten_bbox = 0.000000 %
#
#  1926: 0.077570, 0.105164 avg loss, 0.000100 rate, 2.759135 seconds, 30816 images, 0.086056 hours left
# Loaded: 0.000038 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.678625), count: 1, class_loss = 0.647690, iou_loss = 0.394815, total_loss = 1.042505
#  total_bbox = 36682, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# ...

# %%
! chmod +x darknet
